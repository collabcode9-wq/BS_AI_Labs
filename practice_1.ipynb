# %% [markdown]
# ## output

# %%
print("assalamualikum layari")
# Out:
# assalamualikum layari

# %% [markdown]
# ## input

# %%
city=input("enter the name of the city")
print(city)
# Out:
# enter the name of the city lahore
# lahore

# %% [markdown]
# ## variables and type check

# %%
name ="syed muhammad qamran"
age=20
cgpa=3.80
exam_pass=True

# %%
print(type(name))
print(type(age))
print(type(cgpa))
print(type(exam_pass))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ## mathemitical operations arithemetic operaztions and type casting

# %%
num1 =int(input("enter num1 "))
num2 =int(input("enter num2"))

add=num1+num2
add_float=
sub=num1-num2
multiply=num1*num2
divide=float(num1/num2)
power=add**2

print("addtion = ",add)
print("subtraction = ",sub)
print("multiply = ",multiply)
print("divide = ",divide)
print("power = "power)
# Out:
# enter num1  34
# enter num2 56
# addtion =  90
# subtraction =  -22
# multiply =  1904
# divide =  0.6071428571428571
# 8100

# %%
print(num1*name)
# Out:
# syed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamransyed muhammad qamran

# %% [markdown]
# ## print the area of a square

# %%
print("enter the side lenght of square ")
side_lenght=int(input())
area=side_lenght**2
print(area)
# Out:
# enter the side lenght of square
#  56
# 3136

# %% [markdown]
# ## add of float digits/

# %%
num3=float(input("enter float digit 1"))
num4=float(input("enter float digit 2"))

add_float=num3+num4
print(add_float)
# Out:
# enter float digit 1 34.876
# enter float digit 2 34.0986
# 68.9746

# %% [markdown]
# ## the number is graeter or smaller

# %%
a=int(input())
b=int(input())

if a>b:
  print("true")
else:
  print("flase")
# Out:
#  76
#  87
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 7
#       5   print("true")
#       6 else:
# ----> 7   print("flase")
#
# TypeError: 'bool' object is not callable
